# %% [markdown]
# * This code generates a list of city names for us when provided with a list of coordinates.
# * CitiPy is being utilized in the for loop to add cities for every pair of coordinates in our list.
# * Students will be responsible for determining precisely how to do this in their homework assignment as well.
# * [citipy documentation](https://github.com/wingchen/citipy)

# %%
# Dependencies
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
positive_df = pd.read_csv('Resources/cities.csv')

# %%
positive_df.reset_index(drop=True,inplace=True)

# %%
results = []

for coord in positive_df.itertuples(index=False):    
    
    countryname = coord[0]
    cityname = coord[1]
    cloudiness = coord[2]
    country = coord[3]
    humidity = coord[5]
    lat = coord[6]
    lng = coord[7]
    maxtemp = coord[8]
    windspeed = coord[9]
    
    city_data = {'City': [cityname], 'Latitude': [lat], 'Lng': [lng], 'Cloudiness': [cloudiness], 'Country': [countryname], 'Humidity': [humidity], 'Max Temperature': [maxtemp], 'Wind Speed': [windspeed]}
    df = pd.DataFrame(data=city_data)
    results.append(df) # append this loop's city data frame to the list of dataframes

# %%
city_data_pd = pd.concat(results) # Concat list of data frames in results from above to the final data frame
city_data_pd.head()
latdata = city_data_pd["Latitude"]
tempdata = city_data_pd["Max Temperature"]
humidity = city_data_pd["Humidity"]
windspeed = city_data_pd["Wind Speed"]
cloudiness = city_data_pd["Cloudiness"]

# %%
city_data_pd.plot(kind="scatter", x="Latitude", y="Max Temperature", alpha=0.4, title="Latitude vs. Max Temperature (F)", color="darkblue")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
city_data_pd.plot(kind="scatter", x="Latitude", y="Humidity", alpha=0.4, title="Latitude vs. Humidity", color="darkblue")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
city_data_pd.plot(kind="scatter", x="Latitude", y="Wind Speed", alpha=0.4, title="Latitude vs. Wind Speed", color="darkblue")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
city_data_pd.plot(kind="scatter", x="Latitude", y="Cloudiness", alpha=0.4, title="Latitude vs. Cloudiness", color="darkblue")
# Out:
# <img src="data:image/png;base64,..." width="640">
